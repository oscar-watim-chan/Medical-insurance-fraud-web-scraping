# %% [markdown]
# # Criminal and Civil Enforcement Data cleaning (Stage 1 - Reformatting)
#
# Objectives:
# - Relocate the geographical locations correctly
# - Add new column for the source of database (Year - To see if it matches the date of the entry on the website or not)
# - Reformat the date if necessary
#
# - For early years: Get the geographical location as it's relatively straightforward
#
#
# Next Stage includes:
# - Identifying location and amount of money involved using `money-parser`
#
# Remark:
# This code has been written at the beginning stages when I learnt Python. While I realized it may not be the most efficient way to work on data cleaning year-by-year, I wanted to check on any missing records or rows that are not recorded properly each year carefully, since the HTML code structures for the archived pages each year are slightly different. But I am open to ideas to optimize the code for the data cleaning procedures for the archived years.

# %%
import pandas
import numpy as np

# %%
# Initialize the dataframe
df_output = pandas.DataFrame()

# %% [markdown]
# # Data cleaning for 2019 onwards (can be executed directly)

# %%
# Determine the current year
import datetime
current_year = datetime.datetime.now().year

# %%
for year in range(2019,current_year+1):
    filename = 'OIG_HHS_Scrape_' + str(year)
    df = pandas.read_csv('Raw/'+ filename + '_raw.csv') 
    
    #Rename columns for further command processing
    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

    # Find out records with missing geographical subdivision or location
    df['Flag'] = np.where((df['geographical_subdivision'].isnull()) & (df['authority']!='U.S. Department of Justice'), 1, 0)
    df[df['Flag']==1]
    
    df2=df   # Save a temporary dataframe for reference later if necessary
    
    # Correct format of date
    if year==2019:
        df.date = df.date.str.replace('June 11 2019', 'June 11, 2019')
        df.date = df.date.str.replace('July 5,2019', 'July 5, 2019')
        df['date'] = pandas.to_datetime(df['date'])  
    
    
    # Append individual year to the full dataset
    df_output = df_output.append(df, ignore_index=True)

# %% [markdown]
# ##  2018 Data cleaning

# %%
filename = 'OIG_HHS_Scrape_2018'
df = pandas.read_csv('raw/'+filename + '_raw.csv')

# %%
#2018 Data cleaning

#Rename columns for further command processing
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# Find out records with missing geographical subdivision or location
df['Flag'] = np.where((df['geographical_subdivision'].isnull()) & (df['authority']!='U.S. Department of Justice'), 1, 0)

# Replace each record individually to keep format consistent
list_copied = ['Western District of Virginia', 'District of Puerto Rico']
df['geographical_subdivision'] = np.where((df['geographical_subdivision'].isnull()) & ((df['authority'].isin(list_copied) == True)), 
                      df['authority'],  df['geographical_subdivision'])

df['geographical_subdivision'] = np.where((df['geographical_subdivision'].isnull()) & (df['authority']=='Louisiana Attorney General'), 
                      'Louisiana',  df['geographical_subdivision'])

df['geographical_subdivision'] = np.where((df['geographical_subdivision'].isnull()) & (df['authority']=='U.S. Attorney Northern District of New York'), 
                      'Northern District of New York',  df['geographical_subdivision'])
df['authority'] = np.where((df['authority']=='U.S. Attorney Northern District of New York'), 
                      'U.S. Attorney', df['authority'])

df[df['Flag']==1]
# Out:
#      unnamed:_0                         section               date  \
# 83           83  Criminal and Civil Enforcement    October 9, 2018
# 215         215  Criminal and Civil Enforcement       May 18, 2018
# 309         309  Criminal and Civil Enforcement  February 22, 2018
# 311         311  Criminal and Civil Enforcement  February 21, 2018
#
#                         authority       geographical_subdivision  \
# 83   Western District of Virginia   Western District of Virginia
# 215                 U.S. Attorney  Northern District of New York
# 309       District of Puerto Rico        District of Puerto Rico
# 311    Louisiana Attorney General                      Louisiana
#
#      medicare_fraud_strike_force_case  \
# 83                                  0
# 215                                 0
# 309                                 0
# 311                                 0
#
#                                                heading  \
# 83   Psychiatrist Pleads Guilty to Healthcare Fraud...
# 215  Kinderhook Podiatrist Sentenced for Health Car...
# 309  Mi Salud Program Technician Sentenced To Four ...
# 311  Two Louisiana Women Arrested for Medicaid Welf...
#
#                                            description  \
# 83   Abingdon, VIRGINIA - A former psychiatrist who...
# 215  ALBANY, NEW YORK - Perrin D. Edwards, D.P.M., ...
# 309  SAN JUAN, P.R. - On February 22, 2018, defenda...
# 311  BATON ROUGE, LA - Louisiana Attorney General J...
#
#                                              hyperlink  Flag
# 83   https://www.justice.gov/usao-wdva/pr/psychiatr...     1
# 215  https://www.justice.gov/usao-ndny/pr/kinderhoo...     1
# 309  https://www.justice.gov/usao-pr/pr/mi-salud-pr...     1
# 311           http://www.ag.state.la.us/Article/6537/5     1

# %%
# Add source of year (verify if year match with the date)
df['Source'] = 2017

# %%
# Append individual year to the full dataset
df_output = df_output.append(df, ignore_index=True)

# %% [markdown]
# # 2017 Data cleaning

# %%
filename = 'OIG_HHS_Scrape_2017'
df = pandas.read_csv('raw/'+filename + '_raw.csv') 


#Rename columns for further command processing
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')


# Find out records with missing geographical subdivision or location
df['Flag'] = np.where((df['geographical_subdivision'].isnull()) & (df['authority']!='U.S. Department of Justice'), 1, 0)

list_copied = ['Middle District of Florida', 'District of Idaho']
df['geographical_subdivision'] = np.where((df['geographical_subdivision'].isnull()) & (df['authority'].isin(list_copied) == True), 
                        df['authority'], df['geographical_subdivision'])
df['authority'] = np.where((df['authority'].isin(list_copied) == True), '', df['authority'])

df['geographical_subdivision'] = np.where((df['geographical_subdivision'].isnull()) & (df['authority']=='New York Attorney General'), 
                        'New York', df['geographical_subdivision'])

# %%
# Add source of year (verify if year match with the date)
df['Source'] = 2017

# %%
# Append individual year to the full dataset
df_output = df_output.append(df, ignore_index=True)

# %% [markdown]
# # 2016 Data cleaning

# %%
filename = 'OIG_HHS_Scrape_2016'
df = pandas.read_csv('Raw/'+filename + '_raw.csv') 


#Rename columns for further command processing
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')


# Find out records with missing geographical subdivision or location
df['Flag'] = np.where((df['geographical_subdivision'].isnull()) & (df['authority']!='U.S. Department of Justice'), 1, 0)


df['geographical_subdivision'] = np.where((df['Flag']==1), df['authority'], df['geographical_subdivision'])
df['authority'] = np.where((df['Flag']==1), '', df['authority'])

# %%
# Add source of year (verify if the date matches with the source)
df['Source'] = 2016

# %%
# Append individual year to the full dataset
df_output = df_output.append(df, ignore_index=True)

# %% [markdown]
# # 2015 Data cleaning

# %%
filename = 'OIG_HHS_Scrape_2015'
df = pandas.read_csv('Raw/'+filename + '_raw.csv') 


#Rename columns for further command processing
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')


## Rename authority for an entry in which a space is missing
###########################################
df['authority'] = np.where(df['authority']=='U.S. Departmentof Justice', 'U.S. Department of Justice', df['authority'])



## Fill in geographical subdivision from information in authority section
#####################################################################

# Find out records with missing geographical subdivision or location
authority_exclusion = ['Department of Justice', 'U.S. Department of Justice']   # Excluding those authority that does not have geographical location invovled 


# Separate authority and geog subdivision for authority = "U.S. Attorney" + (subdivision)

df['Flag'] = np.where((df['geographical_subdivision'].isnull()) & (df['authority'].isin(authority_exclusion) == False), 1, 0)

df['geographical_subdivision'] = np.where((df['authority'].str.startswith('U.S. Attorney') == True) & (df['Flag']==1), 
                                          df['authority'].str[14:], df['geographical_subdivision'])

df['authority'] = np.where((df['authority'].str.startswith('U.S. Attorney') == True) & (df['Flag']==1), 
                                        'U.S. Attorney' , df['authority'])


df['geographical_subdivision'] = np.where((df['authority'].str.startswith('U.S. Attorney') == False) &(df['Flag']==1), 
                                            df['authority'], df['geographical_subdivision'])
df['authority'] = np.where((df['authority'].str.startswith('U.S. Attorney') == False) & (df['Flag']==1), '', df['authority'])



## Fill in authority in case it is not able to separate from date
############################################
df['authority']= np.where(df['date'].str.find(';')>0,  df['date'].str[17:], df['authority'])
df['date']= np.where(df['date'].str.find(';')>0,  df['date'].str[0:16], df['date'])

# %%
# Add source of year (verify if year match with the date)
df['Source'] = 2015

# %%
# Append individual year to the full dataset
df_output = df_output.append(df, ignore_index=True)

# %% [markdown]
# # 2014 Data cleaning

# %%
filename = 'OIG_HHS_Scrape_2014'
df = pandas.read_csv('raw/'+filename + '_raw.csv') 





# Rename columns for further command processing
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')


# Find out records with missing geographical subdivision or location
authority_exclusion = ['Department of Justice', 'U.S. Department of Justice']   # Excluding those authority that does not have geographical location invovled 
df['Flag'] = np.where((df['geographical_subdivision'].isnull()) & (df['authority'].isin(authority_exclusion) == False), 1, 0)


# Separate authority and geog subdivision for authority = "U.S. Attorney" + (subdivision)

df['geographical_subdivision'] = np.where((df['authority'].str.startswith('U.S. Attorney') == True) & (df['Flag']==1), 
                                          df['authority'].str[14:], df['geographical_subdivision'])

df['authority'] = np.where((df['authority'].str.startswith('U.S. Attorney') == True) & (df['Flag']==1), 
                                        'U.S. Attorney' , df['authority'])


df['geographical_subdivision'] = np.where((df['authority'].str.startswith('U.S. Attorney') == False) &(df['Flag']==1), 
                                            df['authority'], df['geographical_subdivision'])
df['authority'] = np.where((df['authority'].str.startswith('U.S. Attorney') == False) & (df['Flag']==1), '', df['authority'])





## Fill in authority in case it is not able to separate from date
############################################

df['authority']= np.where(df['date'].str.find(';')>0,  df['date'].str[17:], df['authority'])
df['date']= np.where(df['date'].str.find(';')>0,  df['date'].str[0:16], df['date'])

# %%
# Standardize format of date

#(1) Remove the days of week in some of the entry
weekdays_replace = ['Sunday, ', 'Monday, ', 'Tuesday, ', 'Wednesday, ', 'Thursday, ', 'Friday, ', 'Saturday, ']
for days in weekdays_replace:
    df['date'] = df.date.str.replace(days, '')

# %%
#(2) Add back the year if year is missing
df['date'] = np.where(df.date.str[-6:-5]!=',', df.date.astype(str) + ', 2014', df.date)

# %%
# Add source of year (verify if year match with the date)
df['Source'] = 2014

# %%
# Append individual year to the full dataset
df_output = df_output.append(df, ignore_index=True)

# %% [markdown]
# ## 2013 Data cleaning

# %%
filename = 'OIG_HHS_Scrape_2013'
df = pandas.read_csv('Raw/'+filename + '_raw.csv') 


# Rename columns for further command processing
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')


# Find out records with missing geographical subdivision or location
df['Flag'] = np.where((df['geographical_subdivision'].isnull()) & (df['authority'].isin(authority_exclusion) == False), 1, 0)

# Separate authority and geog subdivision for authority = "U.S. Attorney" + (subdivision)
df['geographical_subdivision'] = np.where((df['authority'].str.startswith('U.S. Attorney') == True) & (df['Flag']==1), 
                                          df['authority'].str[14:], df['geographical_subdivision'])
df['authority'] = np.where((df['authority'].str.startswith('U.S. Attorney') == True) & (df['Flag']==1), 
                                        'U.S. Attorney' , df['authority'])

# Minor edition in format of geographical sublocation
df['geographical_subdivision'] = np.where((df['geographical_subdivision'].str.startswith('for the') == True) & (df['Flag']==1), 
                                       df.geographical_subdivision.str.replace('for the ', '') , df['geographical_subdivision'])

# %%
# Add source of year (verify if year match with the date)
df['Source'] = 2013

# %%
# Append individual year to the full dataset
df_output = df_output.append(df, ignore_index=True)

# %% [markdown]
# ## 2012 Data cleaning

# %%
year = 2012

filename = 'OIG_HHS_Scrape_' + str(year)
df = pandas.read_csv('Raw/'+filename + '_raw.csv') 


# Rename columns for further command processing
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')


# Find out records with missing geographical subdivision or location
df['Flag'] = np.where((df['geographical_subdivision'].isnull()) & (df['authority'].isin(authority_exclusion) == False), 1, 0)

# Separate authority and geog subdivision for authority = "U.S. Attorney" + (subdivision)
df['geographical_subdivision'] = np.where((df['authority'].str.startswith('U.S. Attorney') == True) & (df['Flag']==1), 
                                          df['authority'].str[14:], df['geographical_subdivision'])
df['authority'] = np.where((df['authority'].str.startswith('U.S. Attorney') == True) & (df['Flag']==1), 
                                        'U.S. Attorney' , df['authority'])

# Minor edition in format of geographical sublocation
df['geographical_subdivision'] = np.where((df['geographical_subdivision'].str.startswith('for the') == True) & (df['Flag']==1), 
                                       df.geographical_subdivision.str.replace('for the ', '') , df['geographical_subdivision'])

# %%
# Add source of year (verify if year match with the date)
df['Source'] = year

# %%
# Separate those records with authority/geographical subdivision info mixed in geog location

df['Flag'] = np.where(df['date'].str.find(':')>0, 1, 0)

df['geographical_subdivision'] = np.where(df.date.str[-13:] == 'U.S. Attorney', df['authority'], df['geographical_subdivision'])
df['authority'] = np.where(df.date.str[-13:] == 'U.S. Attorney', 'U.S. Attorney' , df['authority'])
df['date'] = np.where(df.date.str[-13:] == 'U.S. Attorney', df.date.str.replace(': U.S. Attorney','') , df['date'])


df['geographical_subdivision'] = np.where(df.date.str[-len('Eastern District of Tennessee'):] == 'Eastern District of Tennessee', 
                                          'Eastern District of Tennessee', df['geographical_subdivision'])
df['date'] = np.where(df.date.str[-len('Eastern District of Tennessee'):] == 'Eastern District of Tennessee', 
                      df.date.str.replace(': Eastern District of Tennessee','') , df['date'])



df[df['Flag']==1]
# Out:
#      unnamed:_0                         section              date  \
# 39           39  Criminal and Civil Enforcement  December 3, 2012
# 307         307  Criminal and Civil Enforcement      May 11, 2012
#
#          authority       geographical_subdivision  \
# 39             NaN  Eastern District of Tennessee
# 307  U.S. Attorney   Eastern District of Michigan
#
#      medicare_fraud_strike_force_case  \
# 39                                  0
# 307                                 0
#
#                                                heading  \
# 39   The United States has filed a Complaint-in-Int...
# 307  Detroit-area Physician Convicted in $6.7 Milli...
#
#                                            description  \
# 39                                                 NaN
# 307  A federal jury sitting in Detroit, Michigan, c...
#
#                                              hyperlink  Flag  Source
# 39   /fraud/enforcement/criminal/2012/Life_Care_Com...     1    2012
# 307  https://www.justice.gov/usao/mie/news/2012/201...     1    2012

# %%
# Append individual year to the full dataset
df_output = df_output.append(df, ignore_index=True)

# %% [markdown]
# ## 2011 Data cleaning

# %%
year = 2011

filename = 'OIG_HHS_Scrape_' + str(year)
df = pandas.read_csv('Raw/'+filename + '_raw.csv') 

# # Rename columns for further command processing
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
## Split date and authority

df['Flag'] =  np.where((df['authority'].isnull()) & 
                       (df['geographical_subdivision'].isnull()) & (df['date'].str.endswith(str(year)) == False), 1,0)

df['authority'] = np.where((df['authority'].isnull()) & 
                           (df['geographical_subdivision'].isnull()) & (df['date'].str.endswith(str(year)) == False),
                            df['date'].str.split(", 2011, ").str[1], df['authority'] )

df['date'] = np.where((df['Flag']==1), df['date'].str.split(", 2011, ").str[0].astype(str)+', ' + str(year), df['date'] )


df[df['Flag']==1]
# Out:
#      unnamed:_0                         section                date  \
# 271         271  Criminal and Civil Enforcement      March 29, 2011
# 275         275  Criminal and Civil Enforcement      March 28, 2011
# 278         278  Criminal and Civil Enforcement      March 24, 2011
# 279         279  Criminal and Civil Enforcement      March 23, 2011
# 280         280  Criminal and Civil Enforcement      March 16, 2011
# 281         281  Criminal and Civil Enforcement      March 15, 2011
# 282         282  Criminal and Civil Enforcement      March 15, 2011
# 283         283  Criminal and Civil Enforcement      March 14, 2011
# 284         284  Criminal and Civil Enforcement      March 11, 2011
# 285         285  Criminal and Civil Enforcement      March 11, 2011
# 286         286  Criminal and Civil Enforcement      March 11, 2011
# 287         287  Criminal and Civil Enforcement       March 9, 2011
# 288         288  Criminal and Civil Enforcement       March 7, 2011
# 289         289  Criminal and Civil Enforcement       March 7, 2011
# 290         290  Criminal and Civil Enforcement       March 7, 2011
# 291         291  Criminal and Civil Enforcement       March 4, 2011
# 292         292  Criminal and Civil Enforcement       March 4, 2011
# 293         293  Criminal and Civil Enforcement       March 4, 2011
# 294         294  Criminal and Civil Enforcement       March 2, 2011
# 295         295  Criminal and Civil Enforcement       March 2, 2011
# 296         296  Criminal and Civil Enforcement   February 25, 2011
# 297         297  Criminal and Civil Enforcement   February 24, 2011
# 298         298  Criminal and Civil Enforcement   February 24, 2011
# 299         299  Criminal and Civil Enforcement   February 24, 2011
# 300         300  Criminal and Civil Enforcement   February 23, 2011
# 301         301  Criminal and Civil Enforcement   February 23, 2011
# 302         302  Criminal and Civil Enforcement   February 23, 2011
# 303         303  Criminal and Civil Enforcement   February 22, 2011
# 377  Houston Doctor Sentenced to 41 Months in Priso...
#
#                                 description  \
# 271                                     NaN
# 275                                     NaN
# 278                                     NaN
# 279                                     NaN
# 280                                     NaN
# 281                                     NaN
# 282                                     NaN
# 283                                     NaN
# 284                                     NaN
# 285                                     NaN
# 286                                     NaN
# 287                                     NaN
# 288                                     NaN
# 289                                     NaN
# 290                                     NaN
# 291                                     NaN
# 292                                     NaN
# 293                                     NaN
# 294                                     NaN
# 295                                     NaN
# 296                                     NaN
# 297                                     NaN
# 298                                     NaN
# 299                                     NaN
# 300                                     NaN
# 301                                     NaN
# 302                                     NaN
# 303                                     NaN
# 304                                     NaN
# 305                                     NaN
# ..                                      ...
# 347                                     NaN
# 348                                     NaN
# 349                                     NaN
# 350                                     NaN
# 351                                     NaN
# 352                                     NaN
# 353                                     NaN
# 354                                     NaN
# 355                                     NaN
# 356                                     NaN
# 357  (Not Posted to DOJ Site at this Time)
# 358                                     NaN
# 359                                     NaN
# 360                                     NaN
# 361                                     NaN
# 362                                     NaN
# 363                                     NaN
# 364                                     NaN
# 365                                     NaN
# 366                                     NaN
# 367                                     NaN
# 369                                     NaN
# 370                                     NaN
# 371                                     NaN
# 372                                     NaN
# 373                                     NaN
# 374                                     NaN
# 375                                     NaN
# 376                                     NaN
# 377                                     NaN
#
#                                              hyperlink  Flag
# 271  http://washingtondc.fbi.gov/dojpressrel/pressr...     1
# 275  https://www.justice.gov/usao/gan/press/2011/03...     1
# 278  https://www.justice.gov/usao/ins/press_release...     1
# 279  https://www.justice.gov/usao/mie/news/2011/201...     1
# 280  http://jackson.fbi.gov/dojpressrel/pressrel11/...     1
# 281  https://www.justice.gov/opa/pr/2011/March/11-a...     1
# 282  https://www.justice.gov/usao/pam/press_release...     1
# 283  http://www.ag.ny.gov/media_center/2011/mar/mar...     1
# 284  https://www.justice.gov/usao/ils/News/2011/Mar...     1
# 285  https://www.justice.gov/opa/pr/2011/March/11-c...     1
# 286  https://www.justice.gov/usao/fls/PressReleases...     1
# 287  http://houston.fbi.gov/dojpressrel/pressrel11/...     1
# 288  https://www.justice.gov/usao/nj/Press/files/Go...     1
# 289  https://www.justice.gov/usao/txs/releases/Marc...     1
# 290  https://www.justice.gov/opa/pr/2011/March/11-c...     1
# 291  https://www.justice.gov/opa/pr/2011/March/11-c...     1
# 292  https://www.justice.gov/usao/txe/news_release/...     1
# 293  http://indianapolis.fbi.gov/dojpressrel/pressr...     1
# 294  http://tampa.fbi.gov/dojpressrel/pressrel11/ta...     1
# 295  https://www.justice.gov/opa/pr/2011/March/11-c...     1
# 296  https://www.justice.gov/usao/txs/releases/Febr...     1
# 297  https://www.justice.gov/usao/iln/pr/chicago/20...     1
# 298  https://www.justice.gov/usao/pam/press_release...     1
# 299  https://www.justice.gov/usao/ncw/press/lavonne...     1
# 300  https://www.justice.gov/usao/txs/releases/Febr...     1
# 301  https://www.justice.gov/usao/tnw/news/2011/FEB...     1
# 302  https://www.justice.gov/usao/lae/news/2011/201...     1
# 303  http://atlanta.fbi.gov/dojpressrel/pressrel11/...     1
# 304  http://law.ga.gov/00/press/detail/0,2668,87670...     1
# 305  https://www.justice.gov/usao/cae/news/docs/201...     1
# ..                                                 ...   ...
# 347  https://www.justice.gov/opa/pr/2011/February/1...     1
# 348  https://www.justice.gov/opa/pr/2011/February/1...     1
# 349     http://www.in.gov/portal/news_events/67020.htm     1
# 350  https://www.justice.gov/opa/pr/2011/February/1...     1
# 351  https://www.justice.gov/usao/mow/news2011/bake...     1
# 352  https://www.justice.gov/opa/pr/2011/February/1...     1
# 353  http://www.doj.state.or.us/releases/2011/rel02...     1
# 354  https://www.justice.gov/usao/sd/pressreleases/...     1
# 355  https://www.justice.gov/opa/pr/2011/February/1...     1
# 356  https://www.justice.gov/opa/pr/2011/February/1...     1
# 357                                                NaN     1
# 358  https://www.justice.gov/usao/pae/News/Pr/2011/...     1
# 359   https://www.justice.gov/usao/mn/press/feb012.pdf     1
# 360  http://oklahomacity.fbi.gov/dojpressrel/pressr...     1
# 361  https://www.justice.gov/usao/ins/press_release...     1
# 362  https://www.justice.gov/usao/wvn/news/2011/feb...     1
# 363  https://www.justice.gov/opa/pr/2011/February/1...     1
# 364  https://www.justice.gov/opa/pr/2011/February/1...     1
# 365  https://www.oag.state.tx.us/alerts/alerts_view...     1
# 366  https://www.justice.gov/usao/txs/releases/Febr...     1
# 367  https://www.justice.gov/usao/lam/press/press11...     1
# 369  https://www.justice.gov/opa/pr/2011/January/11...     1
# 370  https://www.justice.gov/opa/pr/2011/January/11...     1
# 371  https://www.justice.gov/usao/nys/pressreleases...     1
# 372  https://www.justice.gov/usao/ct/Press2011/2011...     1
# 373  https://www.justice.gov/usao/nj/press/press/fi...     1
# 374  https://www.justice.gov/usao/md/Public-Affairs...     1
# 375  https://www.justice.gov/opa/pr/2011/January/11...     1
# 376  https://www.justice.gov/opa/pr/2011/January/11...     1
# 377  https://www.justice.gov/opa/pr/2011/January/11...     1
#
# [100 rows x 10 columns]

# %%
# Shift geographical info. in "authority" field to correct position

df['Flag'] = np.where((df['geographical_subdivision'].isnull()) & (df['date'].str.endswith(str(year)) == False), 1, 0 )

df['geographical_subdivision'] = np.where(df['Flag']==1, df['authority'], df['geographical_subdivision'] )


df['authority'] = np.where(df['Flag']==1,
                            df['date'].str.split(", 2011 - ").str[1], df['authority'] )

df['date'] = np.where((df['Flag']==1), df['date'].str.split(", 2011 - ").str[0].astype(str)+', ' + str(year), df['date'] )

# %%
# Find out records with missing geographical subdivision or location
authority_exclusion = ['Department of Justice', 'U.S. Department of Justice']   # Excluding those authority that does not have geographical location invovled 
df['Flag'] = np.where((df['geographical_subdivision'].isnull()) & (df['authority'].isin(authority_exclusion) == False), 1, 0)



# Separate authority and geog subdivision for authority = "U.S. Attorney" + (subdivision)
df['geographical_subdivision'] = np.where((df['authority'].str.startswith('U.S. Attorney\'s Office, ')==True)  & (df['Flag']==1), 
                                          df['authority'].str.split('U.S. Attorney\'s Office,').str[1], df['geographical_subdivision'])
df['authority'] = np.where((df['authority'].str.startswith('U.S. Attorney\'s Office, ')==True)  & (df['Flag']==1), 
                                          'U.S. Attorney\'s Office', df['authority'])


df['geographical_subdivision'] = np.where((df['authority'].str.startswith('U.S. Attorney') == True) &
                                          (df['authority'].str.startswith('U.S. Attorney\'s Office')==False)  & (df['Flag']==1), 
                                           df['authority'].str.lstrip('U.S. Attorney ') , df['geographical_subdivision'])


df['authority'] = np.where((df['authority'].str.startswith('U.S. Attorney') == True) &
                                          (df['authority'].str.startswith('U.S. Attorney\'s Office')==False)  & (df['Flag']==1), 
                                          'U.S. Attorney' , df['authority'])

# # # Minor edition in format of geographical sublocation
df['geographical_subdivision'] = np.where((df['geographical_subdivision'].str.startswith('for the') == True) & (df['Flag']==1), 
                                       df.geographical_subdivision.str.replace('for the ', '') , df['geographical_subdivision'])
df['geographical_subdivision'] = np.where((df['geographical_subdivision'].str.startswith(', ') == True) & (df['Flag']==1), 
                                       df.geographical_subdivision.str.replace(', ', '') , df['geographical_subdivision'])

df[df['Flag']==1]
# Out:
#      unnamed:_0                         section                date  \
# 13           13  Criminal and Civil Enforcement   December 12, 2011
# 97           97  Criminal and Civil Enforcement    October 11, 2011
# 112         112  Criminal and Civil Enforcement  September 28, 2011
# 137         137  Criminal and Civil Enforcement   September 7, 2011
# 198         198  Criminal and Civil Enforcement       July 13, 2011
# 201         201  Criminal and Civil Enforcement       July 11, 2011
# 205         205  Criminal and Civil Enforcement        July 7, 2011
# 221         221  Criminal and Civil Enforcement       June 22, 2011
# 234         234  Criminal and Civil Enforcement       June 10, 2011
# 235         235  Criminal and Civil Enforcement       June 10, 2011
# 236         236  Criminal and Civil Enforcement        June 9, 2011
# 237         237  Criminal and Civil Enforcement        June 8, 2011
# 238         238  Criminal and Civil Enforcement        June 7, 2011
# 239         239  Criminal and Civil Enforcement        June 7, 2011
# 240         240  Criminal and Civil Enforcement        June 2, 2011
# 241         241  Criminal and Civil Enforcement        June 2, 2011
# 242         242  Criminal and Civil Enforcement        June 1, 2011
# 243         243  Criminal and Civil Enforcement        June 1, 2011
# 244         244  Criminal and Civil Enforcement        May 27, 2011
# 245         245  Criminal and Civil Enforcement        May 26, 2011
# 246         246  Criminal and Civil Enforcement        May 26, 2011
# 247         247  Criminal and Civil Enforcement        May 26, 2011
# 248         248  Criminal and Civil Enforcement        May 26, 2011
# 249         249  Criminal and Civil Enforcement        May 26, 2011
# 250         250  Criminal and Civil Enforcement        May 26, 2011
# 251         251  Criminal and Civil Enforcement        May 24, 2011
# 252         252  Criminal and Civil Enforcement        May 23, 2011
# 253         253  Criminal and Civil Enforcement        May 19, 2011
# 254         254  Criminal and Civil Enforcement        May 18, 2011
# 255         255  Criminal and Civil Enforcement        May 17, 2011
# ..          ...                             ...                 ...
# 334         334  Criminal and Civil Enforcement     January 6, 2011
# 337         337  Criminal and Civil Enforcement   February 25, 2011
# 338         338  Criminal and Civil Enforcement   February 24, 2011
# 339         339  Criminal and Civil Enforcement   February 24, 2011
# 340         340  Criminal and Civil Enforcement   February 24, 2011
# 341         341  Criminal and Civil Enforcement   February 23, 2011
# 341  https://www.justice.gov/usao/txs/releases/Febr...     1
# 342  https://www.justice.gov/usao/tnw/news/2011/FEB...     1
# 343  https://www.justice.gov/usao/lae/news/2011/201...     1
# 344  http://atlanta.fbi.gov/dojpressrel/pressrel11/...     1
# 345  http://law.ga.gov/00/press/detail/0,2668,87670...     1
# 346  https://www.justice.gov/usao/cae/news/docs/201...     1
# 349     http://www.in.gov/portal/news_events/67020.htm     1
# 351  https://www.justice.gov/usao/mow/news2011/bake...     1
# 353  http://www.doj.state.or.us/releases/2011/rel02...     1
# 354  https://www.justice.gov/usao/sd/pressreleases/...     1
# 357                                                NaN     1
# 358  https://www.justice.gov/usao/pae/News/Pr/2011/...     1
# 359   https://www.justice.gov/usao/mn/press/feb012.pdf     1
# 360  http://oklahomacity.fbi.gov/dojpressrel/pressr...     1
# 361  https://www.justice.gov/usao/ins/press_release...     1
# 362  https://www.justice.gov/usao/wvn/news/2011/feb...     1
# 365  https://www.oag.state.tx.us/alerts/alerts_view...     1
# 366  https://www.justice.gov/usao/txs/releases/Febr...     1
# 367  https://www.justice.gov/usao/lam/press/press11...     1
# 368  https://www.justice.gov/opa/pr/2011/January/11...     1
# 371  https://www.justice.gov/usao/nys/pressreleases...     1
# 372  https://www.justice.gov/usao/ct/Press2011/2011...     1
# 373  https://www.justice.gov/usao/nj/press/press/fi...     1
# 374  https://www.justice.gov/usao/md/Public-Affairs...     1
# 375  https://www.justice.gov/opa/pr/2011/January/11...     1
#
# [121 rows x 10 columns]

# %%
# Separating authority and geographical subdivision (More general)

df['Flag'] = np.where(df['authority'].str.find(',') >=0, 1, 0 )

df['geographical_subdivision'] = np.where(df['Flag']==1, df['authority'].str.split(', ', 1).str[-1], df['geographical_subdivision'] )
df['authority'] = np.where(df['Flag']==1, df['authority'].str.split(', ', 1).str[0], df['authority'] )

df[df['Flag']==1]
# Out:
#      unnamed:_0                         section            date  \
# 205         205  Criminal and Civil Enforcement    July 7, 2011
# 248         248  Criminal and Civil Enforcement    May 26, 2011
# 271         271  Criminal and Civil Enforcement  March 29, 2011
# 280         280  Criminal and Civil Enforcement  March 16, 2011
# 287         287  Criminal and Civil Enforcement   March 9, 2011
# 293         293  Criminal and Civil Enforcement   March 4, 2011
# 294         294  Criminal and Civil Enforcement   March 2, 2011
#
#                            authority  geographical_subdivision  \
# 205  Federal Bureau of Investigation          Atlanta Division
# 248                      US Attorney  District of North Dakota
# 271  Federal Bureau of Investigation   Washington Field Office
# 280  Federal Bureau of Investigation      Jackson, Mississippi
# 287  Federal Bureau of Investigation                   Houston
# 293  Federal Bureau of Investigation              Indianapolis
# 294  Federal Bureau of Investigation                     Tampa
#
#      medicare_fraud_strike_force_case  \
# 205                              -999
# 248                              -999
# 271                              -999
# 280                              -999
# 287                              -999
# 293                              -999
# 294                              -999
#
#                                                heading description  \
# 205  Atlanta Radiologist Guilty of Fraudulently Pas...         NaN
# 248  Keplin Sentenced for Illegal Distribution of I...         NaN
# 271  FDA Chemist and Son Charged with Trading on In...         NaN
# 280      Two Men Indicted in Health Care Fraud Scheme          NaN
# 287  Jury Convicts Durable Medical Equipment Busine...         NaN
# 293  Terre Haute Man Charged with Health Care Fraud...         NaN
# 294  Five Former Executives Indicted on Health Care...         NaN
#
#                                              hyperlink  Flag
# 205  https://www.fbi.gov/atlanta/press-releases/201...     1
# 248  https://www.justice.gov/usao/nd/pressreleases/...     1
# 271  http://washingtondc.fbi.gov/dojpressrel/pressr...     1
# 280  http://jackson.fbi.gov/dojpressrel/pressrel11/...     1
# 287  http://houston.fbi.gov/dojpressrel/pressrel11/...     1
# 293  http://indianapolis.fbi.gov/dojpressrel/pressr...     1
# 294  http://tampa.fbi.gov/dojpressrel/pressrel11/ta...     1

# %%
#Removing unnecessary '(',')'symbols from unknown sources

symbol_to_remove = ['\(','\)','\>']
str_cols = [['date'], ['authority'] ,'geographical_subdivision']    # specify columns you want to replace

for col in str_cols:
    for symbol in symbol_to_remove:
        df[col] = df[col].replace(symbol, '', regex=True)

# %%
# Add source of year (verify if year match with the date)
df['Source'] = year

# %%
# Append individual year to the full dataset
df_output = df_output.append(df, ignore_index=True)

# %% [markdown]
# ## 2009 - 2010 Data cleaning

# %%
for year in range(2009,2011):
    filename = 'OIG_HHS_Scrape_' + str(year)
    df = pandas.read_csv('Raw/'+filename + '_raw.csv') 

    # # Rename columns for further command processing
    df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

    df


    ## Split date and authority

    df['Flag'] =  np.where((df['authority'].isnull()) & 
                           (df['geographical_subdivision'].isnull()), 1,0)

    df['authority'] = np.where((df['authority'].isnull()) & 
                               (df['geographical_subdivision'].isnull()) & (df['date'].str.endswith(str(year)) == False),
                                df['date'].str.split(str(year)+',').str[1].str.lstrip(' '), df['authority'] )

    df['date'] = np.where((df['Flag']==1), 
                          (np.where(df['date'].str.split(',').size>1,
                                  df['date'].str.split(',').str[0].astype(str)+', '+df['date'].str.split(',').str[1].astype(str),
                                  df['date'].str.split(',').str[0].astype(str)+' '+df['date'].str.split(',').str[1].astype(str))),
                          df['date'] )


    df[df['Flag']==1]

    # Separating authority and geographical subdivision (More general)

    df['Flag'] = np.where(df['authority'].str.find(',') >=0, 1, 0 )

    df['geographical_subdivision'] = np.where(df['Flag']==1, df['authority'].str.split(', ', 1).str[-1], df['geographical_subdivision'] )
    df['authority'] = np.where(df['Flag']==1, df['authority'].str.split(', ', 1).str[0].str.lstrip(' '), df['authority'] )

    df[df['Flag']==1]



    #Removing unnecessary '(',')'symbols from unknown sources

    symbol_to_remove = ['\(','\)','\>']
    str_cols = [['date'], ['authority'] ,'geographical_subdivision']    # specify columns you want to replace

    for col in str_cols:
        for symbol in symbol_to_remove:
            df[col] = df[col].replace(symbol, '', regex=True)


    # Add source of year (verify if year match with the date)
    df['Source'] = year



    # Append individual year to the full dataset
    df_output = df_output.append(df, ignore_index=True)

# %% [markdown]
# ## Export df_output dataframe to csv output

# %%
# Append individual year to the full dataset
df_output = df_output.drop(['Flag','unnamed:_0'],  axis=1)
df_output.to_csv('Raw/OIG_HHS_Scrape_allyears_intermediate.csv',index=False)
